# %%
#!/usr/bin/env python3

"""
Extensive-form games assignments.

Starting this week, the templates will no longer contain exact function
signatures and there will not be any automated tests like we had for the
normal-form games assignments. Instead, we will provide sample outputs
produced by the reference implementations which you can use to verify
your solutions. The reason for this change is that there are many valid
ways to represent game trees (e.g. flat array-based vs. pointer-based),
information sets and strategies in extensive-form games. Figuring out
the most suitable representations is an important part of assignments
in this block. Unfortunately, this freedom makes automated testing
pretty much impossible.
"""
import matplotlib.pyplot as plt
import numpy as np
import kuhn_poker

class Node:
    def __init__(self, state: kuhn_poker.State, history):
        self.state = state
        self.history = tuple(int(h) for h in history)

class TerminalNode(Node):
    def __init__(self, state: kuhn_poker.State, history):
        super().__init__(state, history)
        self.payoffs = np.array(state.rewards)
        self.is_terminal = True
        

class ChanceNode(Node):
    def __init__(self, state: kuhn_poker.State, history):
        super().__init__(state, history)
        self.children = {} 
        self.is_terminal = False

class PlayerNode(Node):
    def __init__(self, state: kuhn_poker.State, history):
        super().__init__(state, history)
        self.player = int(state.current_player)
        self.children = {} 
        self.is_terminal = False
        self.info_set = self._get_info_set()

    def _get_info_set(self):
        my_card = self.history[self.player]
        betting_history = self.history[2:]
        return (my_card, betting_history)

def traverse_tree(env, state:kuhn_poker.State|None = None, history = None):
    
    info_sets = {}

    def _traverse(curr_state:kuhn_poker.State, curr_history):
        if curr_state.terminated or curr_state.truncated:
            return TerminalNode(curr_state, curr_history)

        if curr_state.is_chance_node:

            node = ChanceNode(curr_state, curr_history)
            probs = curr_state.chance_strategy
            for action, is_legal in enumerate(curr_state.legal_action_mask):
                if is_legal:
                    next_state = env.step(curr_state, action)
                    child = _traverse(next_state, curr_history + [action])

                    node.children[action] = (child, probs[action])

            return node
        
        else: 
            node = PlayerNode(curr_state, curr_history)
            
            
            if node.info_set not in info_sets:
                info_sets[node.info_set] = []
            info_sets[node.info_set].append(node)
            

            for action, is_legal in enumerate(curr_state.legal_action_mask):
                if is_legal:
                    next_state = env.step(curr_state, action)
                    child = _traverse(next_state, curr_history + [action])
                    
                    node.children[action] = child
            return node

    if state is None:
        state = env.init(0)
        history = []
        
    root_node = _traverse(state, history)
    
    return root_node, info_sets


def evaluate(node: Node, strategies):
    """Compute the expected utility of each player in an extensive-form game."""
    if node.is_terminal:
        return node.payoffs

    expected_utility = np.zeros(2)

    if isinstance(node, ChanceNode):
        
        for action, (child_node, prob) in node.children.items():
            child_value = evaluate(child_node, strategies)
            expected_utility += prob * child_value

    elif isinstance(node, PlayerNode):
        
        if node.player in strategies and node.info_set in strategies[node.player]:
            action_probs = strategies[node.player][node.info_set]

        else:
            num_actions = len(node.children)
            action_probs = np.ones(num_actions) / num_actions
        
        for action, child_node in node.children.items():
            prob = action_probs[action]
            

            child_value = evaluate(child_node, strategies)
            

            expected_utility += prob * child_value

    return expected_utility

def compute_best_response(root, player_id, opponent_strategy, info_sets):
    
    cf_reach = {}
    def annotate_cf_reach(node, p_opp_chance):
        cf_reach[node] = p_opp_chance

        if node.is_terminal:
            return

        if isinstance(node, ChanceNode):
            for action, (child, prob) in node.children.items():
                annotate_cf_reach(child, p_opp_chance * prob)
                
        elif isinstance(node, PlayerNode):
            if node.player == player_id:
                for action, child in node.children.items():
                    annotate_cf_reach(child, p_opp_chance)
            else:

                if node.info_set in opponent_strategy:
                    strat = opponent_strategy[node.info_set]
                else:
                    strat = np.ones(len(node.children)) / len(node.children)
                
                for action, child in node.children.items():
                    annotate_cf_reach(child, p_opp_chance * strat[action])

    annotate_cf_reach(root, 1.0)


    br_strategy = {}
    
    
    def get_value(node):
        if node.is_terminal:
            return node.payoffs[player_id]
        
        if isinstance(node, ChanceNode):
            ev = 0.0
            for action, (child, prob) in node.children.items():
                ev += prob * get_value(child)
            return ev
            
        if node.player != player_id:
            ev = 0.0
            if node.info_set in opponent_strategy:
                strat = opponent_strategy[node.info_set]
            else:
                strat = np.ones(len(node.children)) / len(node.children)
                
            for action, child in node.children.items():
                ev += strat[action] * get_value(child)
            return ev

        if node.info_set not in br_strategy:
            nodes_in_set = info_sets[node.info_set]
            num_actions = len(node.children)
            
            action_values = np.zeros(num_actions)
            
            for h_node in nodes_in_set:
                reach_prob = cf_reach[h_node]
                
                for action, child in h_node.children.items():
                    val_child = get_value(child)
                    action_values[action] += reach_prob * val_child            
            
            best_action = np.argmax(action_values)
            
            
            strat_vec = np.zeros(num_actions)
            strat_vec[best_action] = 1.0
            br_strategy[node.info_set] = strat_vec
            
        chosen_strat = br_strategy[node.info_set]
        chosen_action = np.argmax(chosen_strat)
        return get_value(node.children[chosen_action])

    get_value(root)
    
    return br_strategy


def compute_average_strategy(root_node, strategy_a, strategy_b, alpha, player_id):
    """Compute a weighted average of a pair of behavioural strategies for a given player."""
    avg_strategy = {}

    def _traverse(node, reach_a, reach_b):
        if node.is_terminal:
            return

        if isinstance(node, ChanceNode):
            for action, (child, prob) in node.children.items():
                _traverse(child, reach_a, reach_b)

        elif isinstance(node, PlayerNode):
            if node.player == player_id:
                num_actions = len(node.children)
                
                if node.info_set in strategy_a:
                    probs_a = strategy_a[node.info_set]
                else:
                    probs_a = np.ones(num_actions) / num_actions
                    
                if node.info_set in strategy_b:
                    probs_b = strategy_b[node.info_set]
                else:
                    probs_b = np.ones(num_actions) / num_actions

                denom = (1 - alpha) * reach_a + alpha * reach_b
                
                if denom > 0:
                    new_probs = ((1 - alpha) * reach_a * probs_a + 
                                 alpha * reach_b * probs_b) / denom
                else:
                    new_probs = np.ones(num_actions) / num_actions

                avg_strategy[node.info_set] = new_probs

                for action, child in node.children.items():
                    _traverse(
                        child, 
                        reach_a * probs_a[action], 
                        reach_b * probs_b[action]
                    )
            else:
                for action, child in node.children.items():
                    _traverse(child, reach_a, reach_b)

    _traverse(root_node, 1.0, 1.0)
    
    return avg_strategy


def fictitious_play(root, info_sets, num_iters=10):
    """Run Extensive-form Fictitious Play for a given number of iterations."""

    avg_strategies = {} 
    
    for nodes in info_sets.values():
        node = nodes[0]
        pid = node.player
        
        if pid not in avg_strategies:
            avg_strategies[pid] = {}
            
        if node.info_set not in avg_strategies[pid]:
            num_actions = len(node.children)
            avg_strategies[pid][node.info_set] = np.ones(num_actions) / num_actions

    players = sorted(avg_strategies.keys())
    
    history = []

    for t in range(1, num_iters + 1):
        alpha = 1.0 / (t + 1)
        
        next_avg_strategies = {pid: {} for pid in players}
        
        for player_id in players:
            
            opponent_strategy = {}
            for other_pid in players:
                if other_pid != player_id:
                    opponent_strategy.update(avg_strategies[other_pid])
            
            br_strat = compute_best_response(root, player_id, opponent_strategy, info_sets)
            
            current_player_avg = avg_strategies[player_id]
            
            new_player_avg = compute_average_strategy(
                root, 
                current_player_avg, 
                br_strat, 
                alpha, 
                player_id
            )
            
            next_avg_strategies[player_id] = new_player_avg

        avg_strategies = next_avg_strategies
        
        history.append(avg_strategies)

    return history
            
def compute_exploitability(root, info_sets, strategy_sequence, plot=True):
    """Compute and plot the exploitability of a sequence of strategy profiles."""
    exploitability_values = []

    for strategies in strategy_sequence:
        
        current_utilities = evaluate(root, strategies)
        num_players = len(current_utilities)
        
        total_nash_conv = 0.0
        
        for player_id in range(num_players):
            
            opponent_strategy = {}
            for pid, strat in strategies.items():
                if pid != player_id:
                    opponent_strategy.update(strat)
            
            br_strategy = compute_best_response(root, player_id, opponent_strategy, info_sets)
            
            br_profile = strategies.copy()
            br_profile[player_id] = br_strategy
            
            br_utilities = evaluate(root, br_profile)
            br_value = br_utilities[player_id]
            
            incentive = br_value - current_utilities[player_id]
            total_nash_conv += incentive

        exploitability = total_nash_conv / num_players
        exploitability_values.append(exploitability)

    if plot:
        plt.figure(figsize=(10, 6))
        plt.plot(range(len(exploitability_values)), exploitability_values, label='Exploitability')
        plt.xlabel('Iteration')
        plt.ylabel('Exploitability (Avg NashConv)')
        plt.title('Convergence of Exploitability over Time')
        plt.grid(True)
        plt.legend()
        plt.show()

    return exploitability_values

def main() -> None:
    from kuhn_poker import KuhnPokerNumpy as KuhnPoker

    # The implementation of the game is a part of a JAX library called `pgx`.
    # You can find more information about it here: https://www.sotets.uk/pgx/kuhn_poker/
    # We wrap the original implementation to add an explicit chance player and convert
    # everything from JAX arrays to Numpy arrays. There's also a JAX version which you
    # can import using `from kuhn_poker import KuhnPoker` if interested ;)
    env = KuhnPoker()

    # Initialize the environment with a random seed
    state = env.init(0)

    while not (state.terminated or state.truncated):
        if state.is_chance_node:
            uniform_strategy = state.legal_action_mask / np.sum(state.legal_action_mask)
            assert np.allclose(state.chance_strategy, uniform_strategy), (
                'The chance strategy is not uniform!'
            )

        # Pick the first legal action
        action = np.argmax(state.legal_action_mask)

        # Take a step in the environment
        state = env.step(state, action)

    assert np.sum(state.rewards) == 0, 'The game is not zero-sum!'
    assert state.terminated or state.truncated, 'The game is not over!'


if __name__ == '__main__':
    main()

# %%
import numpy as np
import matplotlib.pyplot as plt

def fictitious_play(root, info_sets, num_iters=10):
    """Run Extensive-form Fictitious Play and print detailed logs."""
    
    def get_card_char(card_int):
        return {0: 'J', 1: 'Q', 2: 'K'}[card_int]

    def get_action_name(action_int, history_ints):

        betting_history = history_ints  
        
        if len(betting_history) == 0:
            return "Check" if action_int == 1 else "Bet"
        elif len(betting_history) == 1:
            prev_action = betting_history[0]
            if prev_action == 1 :
                return "Check" if action_int == 1 else "Bet"
            else: 
                return "Fold" if action_int == 1 else "Call"
        elif len(betting_history) == 2:
             return "Fold" if action_int == 1 else "Call"
        return str(action_int)

    def format_infoset_key(info_set_tuple):
        
        card_int, history_ints = info_set_tuple
        
        card_char = get_card_char(card_int)
        
        if len(history_ints) % 2 == 0:
            display_parts = [card_char, '']
        else:
            display_parts = ['', card_char]
        
        current_history = []
        for h in history_ints:
            action_name = get_action_name(h, current_history)
            display_parts.append(action_name)
            current_history.append(h)
            
        return tuple(display_parts)

    def print_strategy_group(iter_num, player_id, strat_dict, is_br=False):

        sorted_keys = sorted(strat_dict.keys(), key=lambda x: (x[0], len(x[1])))
        
        type_str = "BR of" if is_br else "Avg. strategy of"
        opp_str = " against P2's avg. strategy" if is_br and player_id == 0 else \
                  " against P1's avg. strategy" if is_br and player_id == 1 else ""
        
        for info_set in sorted_keys:
            probs = strat_dict[info_set]
            display_key = format_infoset_key(info_set)
            
            card, hist = info_set
            
            action_outputs = []
            num_actions = len(probs)
            for a in range(num_actions):
                a_name = get_action_name(a, hist)
                action_outputs.append((a_name, probs[a]))
            
            action_outputs.sort(key=lambda x: x[0])
            
            probs_str = ", ".join([f"{name}: {p:.5f}" for name, p in action_outputs])
            
            print(f"Iter {iter_num}: {type_str} P{player_id+1}{opp_str} at {display_key}: {probs_str}")

    avg_strategies = {} 
    
    for nodes in info_sets.values():
        node = nodes[0]
        pid = node.player
        if pid not in avg_strategies:
            avg_strategies[pid] = {}
        if node.info_set not in avg_strategies[pid]:
            num_actions = len(node.children)
            avg_strategies[pid][node.info_set] = np.ones(num_actions) / num_actions

    players = sorted(avg_strategies.keys())
    history_log = []

    for t in range(1, num_iters + 1):
        current_utilities = evaluate(root, avg_strategies)
        print(f"Iter {t}: Utility of avg. strategies: {current_utilities[0]:.5f}, {current_utilities[1]:.5f}")

        print_strategy_group(t, 0, avg_strategies[0])
        print_strategy_group(t, 1, avg_strategies[1])

        br_strats = {}
        for player_id in players:
            opponent_strategy = {}
            for other_pid in players:
                if other_pid != player_id:
                    opponent_strategy.update(avg_strategies[other_pid])
            
            br_strats[player_id] = compute_best_response(root, player_id, opponent_strategy, info_sets)
        
        print_strategy_group(t, 0, br_strats[0], is_br=True)
        print_strategy_group(t, 1, br_strats[1], is_br=True)

        alpha = 1.0 / (t + 1)
        next_avg_strategies = {pid: {} for pid in players}
        
        for player_id in players:
            current_player_avg = avg_strategies[player_id]
            new_player_avg = compute_average_strategy(
                root, 
                current_player_avg, 
                br_strats[player_id], 
                alpha, 
                player_id
            )
            next_avg_strategies[player_id] = new_player_avg

        avg_strategies = next_avg_strategies
        history_log.append(avg_strategies)

    return history_log

# %%
from kuhn_poker import KuhnPokerNumpy as KuhnPoker

root_node, info_sets = traverse_tree(env = KuhnPoker())

# %%
history = fictitious_play(root_node, info_sets, num_iters=10)
# Out:
# Iter 1: Utility of avg. strategies: 0.12500, -0.12500
# Iter 1: Avg. strategy of P1 at ('J', ''): Bet: 0.50000, Check: 0.50000
# Iter 1: Avg. strategy of P1 at ('J', '', 'Check', 'Bet'): Call: 0.50000, Fold: 0.50000
# Iter 1: Avg. strategy of P1 at ('Q', ''): Bet: 0.50000, Check: 0.50000
# Iter 1: Avg. strategy of P1 at ('Q', '', 'Check', 'Bet'): Call: 0.50000, Fold: 0.50000
# Iter 1: Avg. strategy of P1 at ('K', ''): Bet: 0.50000, Check: 0.50000
# Iter 1: Avg. strategy of P1 at ('K', '', 'Check', 'Bet'): Call: 0.50000, Fold: 0.50000
# Iter 1: Avg. strategy of P2 at ('', 'J', 'Bet'): Call: 0.50000, Fold: 0.50000
# Iter 1: Avg. strategy of P2 at ('', 'J', 'Check'): Bet: 0.50000, Check: 0.50000
# Iter 1: Avg. strategy of P2 at ('', 'Q', 'Bet'): Call: 0.50000, Fold: 0.50000
# Iter 1: Avg. strategy of P2 at ('', 'Q', 'Check'): Bet: 0.50000, Check: 0.50000
# Iter 1: Avg. strategy of P2 at ('', 'K', 'Bet'): Call: 0.50000, Fold: 0.50000
# Iter 1: Avg. strategy of P2 at ('', 'K', 'Check'): Bet: 0.50000, Check: 0.50000
# Iter 1: BR of P1 against P2's avg. strategy at ('J', ''): Bet: 1.00000, Check: 0.00000
# Iter 1: BR of P1 against P2's avg. strategy at ('J', '', 'Check', 'Bet'): Call: 0.00000, Fold: 1.00000
# Iter 1: BR of P1 against P2's avg. strategy at ('Q', ''): Bet: 1.00000, Check: 0.00000
# Iter 1: BR of P1 against P2's avg. strategy at ('Q', '', 'Check', 'Bet'): Call: 1.00000, Fold: 0.00000
# Iter 1: BR of P1 against P2's avg. strategy at ('K', ''): Bet: 1.00000, Check: 0.00000
# Iter 1: BR of P1 against P2's avg. strategy at ('K', '', 'Check', 'Bet'): Call: 1.00000, Fold: 0.00000
# Iter 1: BR of P2 against P1's avg. strategy at ('', 'J', 'Bet'): Call: 0.00000, Fold: 1.00000
# Iter 1: BR of P2 against P1's avg. strategy at ('', 'J', 'Check'): Bet: 1.00000, Check: 0.00000
# Iter 1: BR of P2 against P1's avg. strategy at ('', 'Q', 'Bet'): Call: 1.00000, Fold: 0.00000
# Iter 1: BR of P2 against P1's avg. strategy at ('', 'Q', 'Check'): Bet: 1.00000, Check: 0.00000
# Iter 1: BR of P2 against P1's avg. strategy at ('', 'K', 'Bet'): Call: 1.00000, Fold: 0.00000
# Iter 1: BR of P2 against P1's avg. strategy at ('', 'K', 'Check'): Bet: 1.00000, Check: 0.00000
# Iter 2: Utility of avg. strategies: -0.03125, 0.03125
# Iter 2: Avg. strategy of P1 at ('J', ''): Bet: 0.75000, Check: 0.25000
# Iter 2: Avg. strategy of P1 at ('J', '', 'Check', 'Bet'): Call: 0.50000, Fold: 0.50000
# Iter 2: Avg. strategy of P1 at ('Q', ''): Bet: 0.75000, Check: 0.25000
# Iter 2: Avg. strategy of P1 at ('Q', '', 'Check', 'Bet'): Call: 0.50000, Fold: 0.50000
# Iter 2: Avg. strategy of P1 at ('K', ''): Bet: 0.75000, Check: 0.25000
# Iter 2: Avg. strategy of P1 at ('K', '', 'Check', 'Bet'): Call: 0.50000, Fold: 0.50000
# Iter 2: Avg. strategy of P2 at ('', 'J', 'Bet'): Call: 0.25000, Fold: 0.75000
# Iter 2: Avg. strategy of P2 at ('', 'J', 'Check'): Bet: 0.75000, Check: 0.25000
# Iter 2: Avg. strategy of P2 at ('', 'Q', 'Bet'): Call: 0.75000, Fold: 0.25000
# Iter 2: Avg. strategy of P2 at ('', 'Q', 'Check'): Bet: 0.75000, Check: 0.25000
# Iter 2: Avg. strategy of P2 at ('', 'K', 'Bet'): Call: 0.75000, Fold: 0.25000
# Iter 2: Avg. strategy of P2 at ('', 'K', 'Check'): Bet: 0.75000, Check: 0.25000
# Iter 2: BR of P1 against P2's avg. strategy at ('J', ''): Bet: 0.00000, Check: 1.00000
# Iter 2: BR of P1 against P2's avg. strategy at ('J', '', 'Check', 'Bet'): Call: 0.00000, Fold: 1.00000
# Iter 2: BR of P1 against P2's avg. strategy at ('Q', ''): Bet: 1.00000, Check: 0.00000
# Iter 2: BR of P1 against P2's avg. strategy at ('Q', '', 'Check', 'Bet'): Call: 1.00000, Fold: 0.00000
# Iter 2: BR of P1 against P2's avg. strategy at ('K', ''): Bet: 0.00000, Check: 1.00000
# Iter 2: BR of P1 against P2's avg. strategy at ('K', '', 'Check', 'Bet'): Call: 1.00000, Fold: 0.00000
# Iter 2: BR of P2 against P1's avg. strategy at ('', 'J', 'Bet'): Call: 0.00000, Fold: 1.00000
# Iter 2: BR of P2 against P1's avg. strategy at ('', 'J', 'Check'): Bet: 1.00000, Check: 0.00000
# Iter 2: BR of P2 against P1's avg. strategy at ('', 'Q', 'Bet'): Call: 1.00000, Fold: 0.00000
# Iter 2: BR of P2 against P1's avg. strategy at ('', 'Q', 'Check'): Bet: 1.00000, Check: 0.00000
# Iter 2: BR of P2 against P1's avg. strategy at ('', 'K', 'Bet'): Call: 1.00000, Fold: 0.00000
# Iter 2: BR of P2 against P1's avg. strategy at ('', 'K', 'Check'): Bet: 1.00000, Check: 0.00000
# Iter 3: Utility of avg. strategies: -0.02315, 0.02315
# Iter 3: Avg. strategy of P1 at ('J', ''): Bet: 0.50000, Check: 0.50000
# Iter 3: Avg. strategy of P1 at ('J', '', 'Check', 'Bet'): Call: 0.16667, Fold: 0.83333
# Iter 3: Avg. strategy of P1 at ('Q', ''): Bet: 0.83333, Check: 0.16667
# Iter 3: Avg. strategy of P1 at ('Q', '', 'Check', 'Bet'): Call: 0.50000, Fold: 0.50000
# Iter 3: Avg. strategy of P1 at ('K', ''): Bet: 0.50000, Check: 0.50000
# Iter 3: Avg. strategy of P1 at ('K', '', 'Check', 'Bet'): Call: 0.83333, Fold: 0.16667
# Iter 3: Avg. strategy of P2 at ('', 'J', 'Bet'): Call: 0.16667, Fold: 0.83333
# Iter 3: Avg. strategy of P2 at ('', 'J', 'Check'): Bet: 0.83333, Check: 0.16667
# Iter 3: Avg. strategy of P2 at ('', 'Q', 'Bet'): Call: 0.83333, Fold: 0.16667
# Iter 3: Avg. strategy of P2 at ('', 'Q', 'Check'): Bet: 0.83333, Check: 0.16667
# Iter 3: Avg. strategy of P2 at ('', 'K', 'Bet'): Call: 0.83333, Fold: 0.16667
# Iter 3: Avg. strategy of P2 at ('', 'K', 'Check'): Bet: 0.83333, Check: 0.16667
# Iter 3: BR of P1 against P2's avg. strategy at ('J', ''): Bet: 0.00000, Check: 1.00000
# Iter 3: BR of P1 against P2's avg. strategy at ('J', '', 'Check', 'Bet'): Call: 0.00000, Fold: 1.00000
# Iter 3: BR of P1 against P2's avg. strategy at ('Q', ''): Bet: 0.00000, Check: 1.00000
# Iter 3: BR of P1 against P2's avg. strategy at ('Q', '', 'Check', 'Bet'): Call: 1.00000, Fold: 0.00000
# Iter 3: BR of P1 against P2's avg. strategy at ('K', ''): Bet: 0.00000, Check: 1.00000
# Iter 3: BR of P1 against P2's avg. strategy at ('K', '', 'Check', 'Bet'): Call: 1.00000, Fold: 0.00000
# Iter 3: BR of P2 against P1's avg. strategy at ('', 'J', 'Bet'): Call: 0.00000, Fold: 1.00000
# Iter 3: BR of P2 against P1's avg. strategy at ('', 'J', 'Check'): Bet: 0.00000, Check: 1.00000
# Iter 3: BR of P2 against P1's avg. strategy at ('', 'Q', 'Bet'): Call: 1.00000, Fold: 0.00000
# Iter 3: BR of P2 against P1's avg. strategy at ('', 'Q', 'Check'): Bet: 0.00000, Check: 1.00000
# Iter 3: BR of P2 against P1's avg. strategy at ('', 'K', 'Bet'): Call: 1.00000, Fold: 0.00000
# Iter 3: BR of P2 against P1's avg. strategy at ('', 'K', 'Check'): Bet: 1.00000, Check: 0.00000
# Iter 4: Utility of avg. strategies: -0.01823, 0.01823
# Iter 4: Avg. strategy of P1 at ('J', ''): Bet: 0.37500, Check: 0.62500
# Iter 4: Avg. strategy of P1 at ('J', '', 'Check', 'Bet'): Call: 0.10000, Fold: 0.90000
# Iter 4: Avg. strategy of P1 at ('Q', ''): Bet: 0.62500, Check: 0.37500
# Iter 4: Avg. strategy of P1 at ('Q', '', 'Check', 'Bet'): Call: 0.83333, Fold: 0.16667
# Iter 4: Avg. strategy of P1 at ('K', ''): Bet: 0.37500, Check: 0.62500
# Iter 4: Avg. strategy of P1 at ('K', '', 'Check', 'Bet'): Call: 0.90000, Fold: 0.10000
# Iter 4: Avg. strategy of P2 at ('', 'J', 'Bet'): Call: 0.12500, Fold: 0.87500
# Iter 4: Avg. strategy of P2 at ('', 'J', 'Check'): Bet: 0.62500, Check: 0.37500
# Iter 4: Avg. strategy of P2 at ('', 'Q', 'Bet'): Call: 0.87500, Fold: 0.12500
# Iter 4: Avg. strategy of P2 at ('', 'Q', 'Check'): Bet: 0.62500, Check: 0.37500
# Iter 4: Avg. strategy of P2 at ('', 'K', 'Bet'): Call: 0.87500, Fold: 0.12500
# Iter 4: Avg. strategy of P2 at ('', 'K', 'Check'): Bet: 0.87500, Check: 0.12500
# Iter 4: BR of P1 against P2's avg. strategy at ('J', ''): Bet: 0.00000, Check: 1.00000
# Iter 4: BR of P1 against P2's avg. strategy at ('J', '', 'Check', 'Bet'): Call: 0.00000, Fold: 1.00000
# Iter 4: BR of P1 against P2's avg. strategy at ('Q', ''): Bet: 0.00000, Check: 1.00000
# Iter 4: BR of P1 against P2's avg. strategy at ('Q', '', 'Check', 'Bet'): Call: 1.00000, Fold: 0.00000
# Iter 4: BR of P1 against P2's avg. strategy at ('K', ''): Bet: 0.00000, Check: 1.00000
# Iter 4: BR of P1 against P2's avg. strategy at ('K', '', 'Check', 'Bet'): Call: 1.00000, Fold: 0.00000
# Iter 4: BR of P2 against P1's avg. strategy at ('', 'J', 'Bet'): Call: 0.00000, Fold: 1.00000
# Iter 4: BR of P2 against P1's avg. strategy at ('', 'J', 'Check'): Bet: 0.00000, Check: 1.00000
# Iter 4: BR of P2 against P1's avg. strategy at ('', 'Q', 'Bet'): Call: 1.00000, Fold: 0.00000
# Iter 4: BR of P2 against P1's avg. strategy at ('', 'Q', 'Check'): Bet: 0.00000, Check: 1.00000
# Iter 4: BR of P2 against P1's avg. strategy at ('', 'K', 'Bet'): Call: 1.00000, Fold: 0.00000
# Iter 4: BR of P2 against P1's avg. strategy at ('', 'K', 'Check'): Bet: 1.00000, Check: 0.00000
# Iter 5: Utility of avg. strategies: -0.02833, 0.02833
# Iter 5: Avg. strategy of P1 at ('J', ''): Bet: 0.30000, Check: 0.70000
# Iter 5: Avg. strategy of P1 at ('J', '', 'Check', 'Bet'): Call: 0.07143, Fold: 0.92857
# Iter 5: Avg. strategy of P1 at ('Q', ''): Bet: 0.50000, Check: 0.50000
# Iter 5: Avg. strategy of P1 at ('Q', '', 'Check', 'Bet'): Call: 0.90000, Fold: 0.10000
# Iter 5: Avg. strategy of P1 at ('K', ''): Bet: 0.30000, Check: 0.70000
# Iter 5: Avg. strategy of P1 at ('K', '', 'Check', 'Bet'): Call: 0.92857, Fold: 0.07143
# Iter 5: Avg. strategy of P2 at ('', 'J', 'Bet'): Call: 0.10000, Fold: 0.90000
# Iter 5: Avg. strategy of P2 at ('', 'J', 'Check'): Bet: 0.50000, Check: 0.50000
# Iter 5: Avg. strategy of P2 at ('', 'Q', 'Bet'): Call: 0.90000, Fold: 0.10000
# Iter 5: Avg. strategy of P2 at ('', 'Q', 'Check'): Bet: 0.50000, Check: 0.50000
# Iter 5: Avg. strategy of P2 at ('', 'K', 'Bet'): Call: 0.90000, Fold: 0.10000
# Iter 5: Avg. strategy of P2 at ('', 'K', 'Check'): Bet: 0.90000, Check: 0.10000
# Iter 5: BR of P1 against P2's avg. strategy at ('J', ''): Bet: 0.00000, Check: 1.00000
# Iter 5: BR of P1 against P2's avg. strategy at ('J', '', 'Check', 'Bet'): Call: 0.00000, Fold: 1.00000
# Iter 5: BR of P1 against P2's avg. strategy at ('Q', ''): Bet: 0.00000, Check: 1.00000
# Iter 5: BR of P1 against P2's avg. strategy at ('Q', '', 'Check', 'Bet'): Call: 1.00000, Fold: 0.00000
# Iter 5: BR of P1 against P2's avg. strategy at ('K', ''): Bet: 1.00000, Check: 0.00000
# Iter 5: BR of P1 against P2's avg. strategy at ('K', '', 'Check', 'Bet'): Call: 1.00000, Fold: 0.00000
# Iter 5: BR of P2 against P1's avg. strategy at ('', 'J', 'Bet'): Call: 0.00000, Fold: 1.00000
# Iter 5: BR of P2 against P1's avg. strategy at ('', 'J', 'Check'): Bet: 0.00000, Check: 1.00000
# Iter 5: BR of P2 against P1's avg. strategy at ('', 'Q', 'Bet'): Call: 1.00000, Fold: 0.00000
# Iter 5: BR of P2 against P1's avg. strategy at ('', 'Q', 'Check'): Bet: 0.00000, Check: 1.00000
# Iter 5: BR of P2 against P1's avg. strategy at ('', 'K', 'Bet'): Call: 1.00000, Fold: 0.00000
# Iter 5: BR of P2 against P1's avg. strategy at ('', 'K', 'Check'): Bet: 1.00000, Check: 0.00000
# Iter 6: Utility of avg. strategies: -0.03588, 0.03588
# Iter 6: Avg. strategy of P1 at ('J', ''): Bet: 0.25000, Check: 0.75000
# Iter 6: Avg. strategy of P1 at ('J', '', 'Check', 'Bet'): Call: 0.05556, Fold: 0.94444
# Iter 6: Avg. strategy of P1 at ('Q', ''): Bet: 0.41667, Check: 0.58333
# Iter 6: Avg. strategy of P1 at ('Q', '', 'Check', 'Bet'): Call: 0.92857, Fold: 0.07143
# Iter 6: Avg. strategy of P1 at ('K', ''): Bet: 0.41667, Check: 0.58333
# Iter 6: Avg. strategy of P1 at ('K', '', 'Check', 'Bet'): Call: 0.92857, Fold: 0.07143
# Iter 6: Avg. strategy of P2 at ('', 'J', 'Bet'): Call: 0.08333, Fold: 0.91667
# Iter 6: Avg. strategy of P2 at ('', 'J', 'Check'): Bet: 0.41667, Check: 0.58333
# Iter 6: Avg. strategy of P2 at ('', 'Q', 'Bet'): Call: 0.91667, Fold: 0.08333
# Iter 6: Avg. strategy of P2 at ('', 'Q', 'Check'): Bet: 0.41667, Check: 0.58333
# Iter 6: Avg. strategy of P2 at ('', 'K', 'Bet'): Call: 0.91667, Fold: 0.08333
# Iter 6: Avg. strategy of P2 at ('', 'K', 'Check'): Bet: 0.91667, Check: 0.08333
# Iter 6: BR of P1 against P2's avg. strategy at ('J', ''): Bet: 0.00000, Check: 1.00000
# Iter 6: BR of P1 against P2's avg. strategy at ('J', '', 'Check', 'Bet'): Call: 0.00000, Fold: 1.00000
# Iter 6: BR of P1 against P2's avg. strategy at ('Q', ''): Bet: 0.00000, Check: 1.00000
# Iter 6: BR of P1 against P2's avg. strategy at ('Q', '', 'Check', 'Bet'): Call: 1.00000, Fold: 0.00000
# Iter 6: BR of P1 against P2's avg. strategy at ('K', ''): Bet: 1.00000, Check: 0.00000
# Iter 6: BR of P1 against P2's avg. strategy at ('K', '', 'Check', 'Bet'): Call: 1.00000, Fold: 0.00000
# Iter 6: BR of P2 against P1's avg. strategy at ('', 'J', 'Bet'): Call: 0.00000, Fold: 1.00000
# Iter 6: BR of P2 against P1's avg. strategy at ('', 'J', 'Check'): Bet: 0.00000, Check: 1.00000
# Iter 6: BR of P2 against P1's avg. strategy at ('', 'Q', 'Bet'): Call: 1.00000, Fold: 0.00000
# Iter 6: BR of P2 against P1's avg. strategy at ('', 'Q', 'Check'): Bet: 0.00000, Check: 1.00000
# Iter 6: BR of P2 against P1's avg. strategy at ('', 'K', 'Bet'): Call: 1.00000, Fold: 0.00000
# Iter 6: BR of P2 against P1's avg. strategy at ('', 'K', 'Check'): Bet: 1.00000, Check: 0.00000
# Iter 7: Utility of avg. strategies: -0.03827, 0.03827
# Iter 7: Avg. strategy of P1 at ('J', ''): Bet: 0.21429, Check: 0.78571
# Iter 7: Avg. strategy of P1 at ('J', '', 'Check', 'Bet'): Call: 0.04545, Fold: 0.95455
# Iter 7: Avg. strategy of P1 at ('Q', ''): Bet: 0.35714, Check: 0.64286
# Iter 7: Avg. strategy of P1 at ('Q', '', 'Check', 'Bet'): Call: 0.94444, Fold: 0.05556
# Iter 7: Avg. strategy of P1 at ('K', ''): Bet: 0.50000, Check: 0.50000
# Iter 7: Avg. strategy of P1 at ('K', '', 'Check', 'Bet'): Call: 0.92857, Fold: 0.07143
# Iter 7: Avg. strategy of P2 at ('', 'J', 'Bet'): Call: 0.07143, Fold: 0.92857
# Iter 7: Avg. strategy of P2 at ('', 'J', 'Check'): Bet: 0.35714, Check: 0.64286
# Iter 7: Avg. strategy of P2 at ('', 'Q', 'Bet'): Call: 0.92857, Fold: 0.07143
# Iter 7: Avg. strategy of P2 at ('', 'Q', 'Check'): Bet: 0.35714, Check: 0.64286
# Iter 7: Avg. strategy of P2 at ('', 'K', 'Bet'): Call: 0.92857, Fold: 0.07143
# Iter 7: Avg. strategy of P2 at ('', 'K', 'Check'): Bet: 0.92857, Check: 0.07143
# Iter 7: BR of P1 against P2's avg. strategy at ('J', ''): Bet: 0.00000, Check: 1.00000
# Iter 7: BR of P1 against P2's avg. strategy at ('J', '', 'Check', 'Bet'): Call: 0.00000, Fold: 1.00000
# Iter 7: BR of P1 against P2's avg. strategy at ('Q', ''): Bet: 0.00000, Check: 1.00000
# Iter 7: BR of P1 against P2's avg. strategy at ('Q', '', 'Check', 'Bet'): Call: 1.00000, Fold: 0.00000
# Iter 7: BR of P1 against P2's avg. strategy at ('K', ''): Bet: 1.00000, Check: 0.00000
# Iter 7: BR of P1 against P2's avg. strategy at ('K', '', 'Check', 'Bet'): Call: 1.00000, Fold: 0.00000
# Iter 7: BR of P2 against P1's avg. strategy at ('', 'J', 'Bet'): Call: 0.00000, Fold: 1.00000
# Iter 7: BR of P2 against P1's avg. strategy at ('', 'J', 'Check'): Bet: 0.00000, Check: 1.00000
# Iter 7: BR of P2 against P1's avg. strategy at ('', 'Q', 'Bet'): Call: 1.00000, Fold: 0.00000
# Iter 7: BR of P2 against P1's avg. strategy at ('', 'Q', 'Check'): Bet: 0.00000, Check: 1.00000
# Iter 7: BR of P2 against P1's avg. strategy at ('', 'K', 'Bet'): Call: 1.00000, Fold: 0.00000
# Iter 7: BR of P2 against P1's avg. strategy at ('', 'K', 'Check'): Bet: 1.00000, Check: 0.00000
# Iter 8: Utility of avg. strategies: -0.03841, 0.03841
# Iter 8: Avg. strategy of P1 at ('J', ''): Bet: 0.18750, Check: 0.81250
# Iter 8: Avg. strategy of P1 at ('J', '', 'Check', 'Bet'): Call: 0.03846, Fold: 0.96154
# Iter 8: Avg. strategy of P1 at ('Q', ''): Bet: 0.31250, Check: 0.68750
# Iter 8: Avg. strategy of P1 at ('Q', '', 'Check', 'Bet'): Call: 0.95455, Fold: 0.04545
# Iter 8: Avg. strategy of P1 at ('K', ''): Bet: 0.56250, Check: 0.43750
# Iter 8: Avg. strategy of P1 at ('K', '', 'Check', 'Bet'): Call: 0.92857, Fold: 0.07143
# Iter 8: Avg. strategy of P2 at ('', 'J', 'Bet'): Call: 0.06250, Fold: 0.93750
# Iter 8: Avg. strategy of P2 at ('', 'J', 'Check'): Bet: 0.31250, Check: 0.68750
# Iter 8: Avg. strategy of P2 at ('', 'Q', 'Bet'): Call: 0.93750, Fold: 0.06250
# Iter 8: Avg. strategy of P2 at ('', 'Q', 'Check'): Bet: 0.31250, Check: 0.68750
# Iter 8: Avg. strategy of P2 at ('', 'K', 'Bet'): Call: 0.93750, Fold: 0.06250
# Iter 8: Avg. strategy of P2 at ('', 'K', 'Check'): Bet: 0.93750, Check: 0.06250
# Iter 8: BR of P1 against P2's avg. strategy at ('J', ''): Bet: 0.00000, Check: 1.00000
# Iter 8: BR of P1 against P2's avg. strategy at ('J', '', 'Check', 'Bet'): Call: 0.00000, Fold: 1.00000
# Iter 8: BR of P1 against P2's avg. strategy at ('Q', ''): Bet: 0.00000, Check: 1.00000
# Iter 8: BR of P1 against P2's avg. strategy at ('Q', '', 'Check', 'Bet'): Call: 1.00000, Fold: 0.00000
# Iter 8: BR of P1 against P2's avg. strategy at ('K', ''): Bet: 1.00000, Check: 0.00000
# Iter 8: BR of P1 against P2's avg. strategy at ('K', '', 'Check', 'Bet'): Call: 1.00000, Fold: 0.00000
# Iter 8: BR of P2 against P1's avg. strategy at ('', 'J', 'Bet'): Call: 0.00000, Fold: 1.00000
# Iter 8: BR of P2 against P1's avg. strategy at ('', 'J', 'Check'): Bet: 0.00000, Check: 1.00000
# Iter 8: BR of P2 against P1's avg. strategy at ('', 'Q', 'Bet'): Call: 1.00000, Fold: 0.00000
# Iter 8: BR of P2 against P1's avg. strategy at ('', 'Q', 'Check'): Bet: 0.00000, Check: 1.00000
# Iter 8: BR of P2 against P1's avg. strategy at ('', 'K', 'Bet'): Call: 1.00000, Fold: 0.00000
# Iter 8: BR of P2 against P1's avg. strategy at ('', 'K', 'Check'): Bet: 1.00000, Check: 0.00000
# Iter 9: Utility of avg. strategies: -0.03755, 0.03755
# Iter 9: Avg. strategy of P1 at ('J', ''): Bet: 0.16667, Check: 0.83333
# Iter 9: Avg. strategy of P1 at ('J', '', 'Check', 'Bet'): Call: 0.03333, Fold: 0.96667
# Iter 9: Avg. strategy of P1 at ('Q', ''): Bet: 0.27778, Check: 0.72222
# Iter 9: Avg. strategy of P1 at ('Q', '', 'Check', 'Bet'): Call: 0.96154, Fold: 0.03846
# Iter 9: Avg. strategy of P1 at ('K', ''): Bet: 0.61111, Check: 0.38889
# Iter 9: Avg. strategy of P1 at ('K', '', 'Check', 'Bet'): Call: 0.92857, Fold: 0.07143
# Iter 9: Avg. strategy of P2 at ('', 'J', 'Bet'): Call: 0.05556, Fold: 0.94444
# Iter 9: Avg. strategy of P2 at ('', 'J', 'Check'): Bet: 0.27778, Check: 0.72222
# Iter 9: Avg. strategy of P2 at ('', 'Q', 'Bet'): Call: 0.94444, Fold: 0.05556
# Iter 9: Avg. strategy of P2 at ('', 'Q', 'Check'): Bet: 0.27778, Check: 0.72222
# Iter 9: Avg. strategy of P2 at ('', 'K', 'Bet'): Call: 0.94444, Fold: 0.05556
# Iter 9: Avg. strategy of P2 at ('', 'K', 'Check'): Bet: 0.94444, Check: 0.05556
# Iter 9: BR of P1 against P2's avg. strategy at ('J', ''): Bet: 0.00000, Check: 1.00000
# Iter 9: BR of P1 against P2's avg. strategy at ('J', '', 'Check', 'Bet'): Call: 0.00000, Fold: 1.00000
# Iter 9: BR of P1 against P2's avg. strategy at ('Q', ''): Bet: 0.00000, Check: 1.00000
# Iter 9: BR of P1 against P2's avg. strategy at ('Q', '', 'Check', 'Bet'): Call: 0.00000, Fold: 1.00000
# Iter 9: BR of P1 against P2's avg. strategy at ('K', ''): Bet: 1.00000, Check: 0.00000
# Iter 9: BR of P1 against P2's avg. strategy at ('K', '', 'Check', 'Bet'): Call: 1.00000, Fold: 0.00000
# Iter 9: BR of P2 against P1's avg. strategy at ('', 'J', 'Bet'): Call: 0.00000, Fold: 1.00000
# Iter 9: BR of P2 against P1's avg. strategy at ('', 'J', 'Check'): Bet: 0.00000, Check: 1.00000
# Iter 9: BR of P2 against P1's avg. strategy at ('', 'Q', 'Bet'): Call: 0.00000, Fold: 1.00000
# Iter 9: BR of P2 against P1's avg. strategy at ('', 'Q', 'Check'): Bet: 0.00000, Check: 1.00000
# Iter 9: BR of P2 against P1's avg. strategy at ('', 'K', 'Bet'): Call: 1.00000, Fold: 0.00000
# Iter 9: BR of P2 against P1's avg. strategy at ('', 'K', 'Check'): Bet: 1.00000, Check: 0.00000
# Iter 10: Utility of avg. strategies: -0.03625, 0.03625
# Iter 10: Avg. strategy of P1 at ('J', ''): Bet: 0.15000, Check: 0.85000
# Iter 10: Avg. strategy of P1 at ('J', '', 'Check', 'Bet'): Call: 0.02941, Fold: 0.97059
# Iter 10: Avg. strategy of P1 at ('Q', ''): Bet: 0.25000, Check: 0.75000
# Iter 10: Avg. strategy of P1 at ('Q', '', 'Check', 'Bet'): Call: 0.83333, Fold: 0.16667
# Iter 10: Avg. strategy of P1 at ('K', ''): Bet: 0.65000, Check: 0.35000
# Iter 10: Avg. strategy of P1 at ('K', '', 'Check', 'Bet'): Call: 0.92857, Fold: 0.07143
# Iter 10: Avg. strategy of P2 at ('', 'J', 'Bet'): Call: 0.05000, Fold: 0.95000
# Iter 10: Avg. strategy of P2 at ('', 'J', 'Check'): Bet: 0.25000, Check: 0.75000
# Iter 10: Avg. strategy of P2 at ('', 'Q', 'Bet'): Call: 0.85000, Fold: 0.15000
# Iter 10: Avg. strategy of P2 at ('', 'Q', 'Check'): Bet: 0.25000, Check: 0.75000
# Iter 10: Avg. strategy of P2 at ('', 'K', 'Bet'): Call: 0.95000, Fold: 0.05000
# Iter 10: Avg. strategy of P2 at ('', 'K', 'Check'): Bet: 0.95000, Check: 0.05000
# Iter 10: BR of P1 against P2's avg. strategy at ('J', ''): Bet: 0.00000, Check: 1.00000
# Iter 10: BR of P1 against P2's avg. strategy at ('J', '', 'Check', 'Bet'): Call: 0.00000, Fold: 1.00000
# Iter 10: BR of P1 against P2's avg. strategy at ('Q', ''): Bet: 0.00000, Check: 1.00000
# Iter 10: BR of P1 against P2's avg. strategy at ('Q', '', 'Check', 'Bet'): Call: 0.00000, Fold: 1.00000
# Iter 10: BR of P1 against P2's avg. strategy at ('K', ''): Bet: 1.00000, Check: 0.00000
# Iter 10: BR of P1 against P2's avg. strategy at ('K', '', 'Check', 'Bet'): Call: 1.00000, Fold: 0.00000
# Iter 10: BR of P2 against P1's avg. strategy at ('', 'J', 'Bet'): Call: 0.00000, Fold: 1.00000
# Iter 10: BR of P2 against P1's avg. strategy at ('', 'J', 'Check'): Bet: 0.00000, Check: 1.00000
# Iter 10: BR of P2 against P1's avg. strategy at ('', 'Q', 'Bet'): Call: 0.00000, Fold: 1.00000
# Iter 10: BR of P2 against P1's avg. strategy at ('', 'Q', 'Check'): Bet: 0.00000, Check: 1.00000
# Iter 10: BR of P2 against P1's avg. strategy at ('', 'K', 'Bet'): Call: 1.00000, Fold: 0.00000
# Iter 10: BR of P2 against P1's avg. strategy at ('', 'K', 'Check'): Bet: 1.00000, Check: 0.00000
